# %% [markdown]
# ## Part ( i ) Baseline Neural Network on Dataset I

# %% [markdown]
# ## Part (ii) SciKit and PyTorch Extension on Dataset I

# %% [markdown]
# ## Comparison of Part ( i ) and ( ii ) Results

# %% [markdown]
# ## Part ( iii ) Baseline Neural Network on Dataset I

# %% [markdown]
# ## Part ( iv ) SciKit and PyTorch Extension on Dataset II

# %% [markdown]
# ## Comparison of Part ( iii ) and ( iv ) results

# %% [markdown]
# ## Summary of Results

# %%
print("test")
# Out:
# test
